# %%
import librosa
from librosa.feature import melspectrogram
import librosa.display as libd

from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

import matplotlib
matplotlib.use("TkAgg")
import matplotlib.pyplot as plt

import pickle
import pandas as pd
import numpy as np
import keras
from keras.layers import Conv1D
from keras.layers import Conv2D
from keras.layers import Dense
from keras.layers import Flatten
from keras.models import Sequential


import os
from ipywidgets import IntProgress, HTML, HBox
from IPython.display import display

seed = 2205
np.random.seed(seed)
sampling_rate = 22050
# Out:
# Using TensorFlow backend.

# %%
def get_spectrogram(wav_filename, show=False):
    """
    Like in the github article, I used windows of 2048 timesteps,
    with 1024 timesteps overlap between spectrogram frames.
    I'm using a sampling frequency of 22.05 kHz.
    """
    y, sr = librosa.load(wav_filename, sr=sampling_rate)
    M = melspectrogram(y, sr, n_fft=2048, hop_length=1024)

    if show:
        print(wav_filename)
        print(" - y.shape", y.shape)
        print(" - M.shape", M.shape, '\n')

        plt.figure(figsize=(12, 8))
        libd.specshow(librosa.power_to_db(M, ref=np.max),
                      y_axis='mel', fmax=None,
                      x_axis='time')
        plt.colorbar(format='%+2.0f dB')
        plt.title('Mel spectrogram')
        plt.tight_layout()
        plt.show(block=False)

    return M

# %%
# audio, sr = librosa.load('data/0_gHGYEljjY2M.wav', sr=sampling_rate)
audio, sr = librosa.load('data/2_oScZuIp6ce8.wav', sr=sampling_rate, offset=25, duration=3)
audio.shape
# Out:
# (66150,)

# %%
raw_data = pd.read_csv('data.csv')
data = raw_data[raw_data['status'] == 'valid'][['year', 'filename']]
decades = np.array(data['year'] - (data['year'] % 10))

encoder = LabelEncoder()
encoder.fit(decades)
classes = encoder.transform(decades)
labels = keras.utils.to_categorical(classes)
labels.shape
# Out:
# (7293, 10)

# %%
new_raw = raw_data.copy()
new_raw['status'] = 'invalid'

file_count = len(os.listdir('data'))
print("files", file_count)
progress = IntProgress(min=0, max=file_count) # instantiate the bar
label = HTML()
box = HBox(children=[progress, label])
display(box)

for filename in os.listdir('data'):
    progress.value += 1
    label.value = u'{name}: {index} / {size}'.format(
                    name='files loaded',
                    index=progress.value,
                    size=file_count
                )
    if filename.endswith(".wav"):
        index = int(filename.split('_')[0])
        new_raw.at[index, 'status'] = 'valid'
        new_raw.at[index, 'filename'] = filename
#         print(os.path.join('data', filename))
new_raw
# Out:
# files 7312
# HBox(children=(IntProgress(value=0, max=7312), HTML(value='')))
#       Unnamed: 0   idx                      artist_name  \
# 0              0     0                           Casual
# 1              1     1                     The Box Tops
# 2              2     2                 Sonora Santanera
# 3              3     3                         Adam Ant
# 4              4     4                              Gob
# 5              5     5            Jeff And Sheri Easter
# 6              6     6                          Rated R
# 7              7     7            Tweeterfriendly Music
# 8              8     8                 Planet P Project
# 9              9     9                              Clp
# 10            10    10                     JennyAnyKind
# 11            11    11                     Wayne Watson
# 12            12    12                        Andy Andy
# 13            13    13                        Bob Azzam
# 14            14    14                    Lionel Richie
# 15            15    15                       Blue Rodeo
# 16            16    16                  Richard Souther
# 17            17    17                    Faiz Ali Faiz
# 18            18    18                            Tesla
# 19            19    19                        lextrical
# 20            20    20                     Jimmy Wakely
# 21            21    21                     Alice Stuart
# 22            22    22                            Elena
# 23            23    23        The Dillinger Escape Plan
# 24            24    24                     SUE THOMPSON
# 25            25    25                   Five Bolt Main
# 26            26    26                              Clp
# 27            27    27                       Tim Wilson
# 28            28    28                      Willie Bobo
# 29            29    29                       Faye Adams
# ...          ...   ...                              ...
# 9970        9970  9970                     Dinosaur Jr.
# 9971        9971  9971                        Sin Plomo
# 9972        9972  9972                    Lloyd Spiegel
# 9973        9973  9973                  The Sex Pistols
# 9974        9974  9974  Toni Braxton Featuring Babyface
# 9975        9975  9975                       Cal Tjader
# 9976        9976  9976                            Aiden
# 9977        9977  9977                      Winterlight
# 9978        9978  9978                       themselves
# 9979        9979  9979                      Ivan Parker
# 9980        9980  9980                          Daara J
# 9981        9981  9981                  New Found Glory
# 9982        9982  9982               Mar√≠a Elena Walsh
# 9983        9983  9983                   Mindy McCready
# 9984        9984  9984                     Joy Division
# 9985        9985  9985                    Don Francisco
# 9986        9986  9986                          Kaskaad
# 9987        9987  9987                 Chantal Chamandy
# 9988        9988  9988           Mouth Of The Architect
# 9989        9989  9989                    It Dies Today
# 9990        9990  9990                   Diamanda Galas
# 9991        9991  9991                 David Arkenstone
# 9992        9992  9992                 Mario Rosenstock
# 9993        9993  9993                    Grandpa Jones
# 9994        9994  9994             Blind Willie Johnson
# 9995        9995  9995                        Moonspell
# 9996        9996  9996                   Danny Williams
# 9997        9997  9997                    Winston Reedy
# 9998        9998  9998         Myrick "Freeze" Guillory
# 9999        9999  9999              Seventh Day Slumber
#
#                                                   title  \
# 0                                      I Didn't Mean To
# 1                                             Soul Deep
# 2                                       Amor De Cabaret
# 3                                       Something Girls
# 4                                        Face the Ashes
# 5           The Moon And I (Ordinary Day Album Version)
# 6                                 Keepin It Real (Skit)
# 7                                          Drop of Rain
# 8                                            Pink World
# 9                     Insatiable (Instrumental Version)
# 10                                      Young Boy Blues
# 11                             The Urgency (LP Version)
# 12                                             La Culpa
# 13                                       Auguri Cha Cha
# 14                              Tonight Will Be Alright
# 15                                             Floating
# 16                                            High Tide
# 17                                 Sohna Nee Sohna Data
# 18                                    Caught In A Dream
# 19                                      Synthetic Dream
# 20                           Broken-Down Merry-Go-Round
# 21                                         Kassie Jones
# 22                                       Setanta matins
# 23                      Setting Fire to Sleeping Giants
# 24                       James (Hold The Ladder Steady)
# 25                                Made Like This (Live)
# 26                                    Superconfidential
# 27    I Think My Wife Is Running Around On Me (Taco ...
# 28                                       Spanish Grease
# 29                                 Crazy Mixed Up World
# ...                                                 ...
# 9970                                      Does It Float
# 9971                         Why can't we live together
# 9972                                          The Storm
# 9973                  My Way (Alternate Studio Version)
# 9974                                    Give U My Heart
# 9975                                   Along Comes Mary
# 9976                                Die Romantic [Live]
# 9977                                           Daybreak
# 9978                                   Crayon Sharpener
# 9979                                Then He Said_ "Sing
# 9980                                       Le Precipice
# 9981                        Don't Let Her Pull You Down
# 9982                                    La Mona Jacinta
# 9983                                Ten Thousand Angels
# 9984                                     Leaders Of Men
# 9985                           Overture (Genesis & Job)
# 9986                                        Mohawk Hunt
# 9987                                            Zindegi
# 9988                            Harboring An Apparition
# 9989                        One the road (to Damnation)
# 9990                             Dark End Of The Street
# 9991                                The Forgotten Lands
# 9992                        Munster Song (Best of 2009)
# 9993                                      Down In Dixie
# 9994                             God Don't Never Change
# 9995                                     The Hanged Man
# 9996                   The Wonderful World Of The Young
# 9997                                    Sentimental Man
# 9998                                  Zydeco In D-Minor
# 9999                                     Shattered Life
#
#                                   release  year              filename  \
# 0                             Fear Itself  1994     0_gHGYEljjY2M.wav
# 1                              Dimensions  1969     1_6VFEIfh2m-g.wav
# 2     Las Numero 1 De La Sonora Santanera  2007     2_oScZuIp6ce8.wav
# 3                           Friend Or Foe  1982     3_dISqPMADs00.wav
# 4                           Muertos Vivos  2007     4_kvZiH1k_5_s.wav
# 5                            Ordinary Day     0                   NaN
# 6                       Da Ghetto Psychic  2003                   NaN
# 7                            Gin & Phonic  2003     7_PrSAS9lf2eA.wav
# 8                              Pink World  1984     8_BSJK6YKLmEQ.wav
# 9                       Superinstrumental  2008     9_YTC8xsagZgY.wav
# 10                             I Need You  2000    10_f5URcnD452c.wav
# 11                           The Way Home  1998    11_6PGsnAbvCFw.wav
# 12                       Placer & Castigo  1981                   NaN
# 13                            Arrivederci     0                   NaN
# 14                 Dancing On The Ceiling  1986    14_8ZZz44Y2DPg.wav
# 15                              Outskirts  1987    15_ODopp17DeOs.wav
# 16                         Cross Currents  1989    16__G7ncNXlScw.wav
# 17                      Panjtan Ka Ghulam     0                   NaN
# 18                                   Gold  2004    18_-Tgtl5FOGNY.wav
# 19          Whatever Happened To Boredom?     0                   NaN
# 20                 1942-1952 Jimmy Wakely  1950    20_z2l7Squ65xs.wav
# 21                     All The Good Times  2002    21_V3S5y-C60xY.wav
# 22                Un cafe_ setanta matins     0                   NaN
# 23                           Miss Machine  2004    23_2dQ2-t_v25g.wav
# 24           Sue Thompson - Her Very Best  1985    24_laEwOj5qXNo.wav
# 25                                   Live  2005    25_SiOQWCrS0G4.wav
# 26                  Strictly Confidential  2008    26_ogTkHhv8-GI.wav
# 27                   The Real Twang Thang  2005    27_iHYIReJEnQI.wav
# 28              Willie Bobo's Finest Hour  1997    28_o34TbQOzhkU.wav
# 29                           Shake A Hand  1961    29_rruPJjeeIAI.wav
# ...                                   ...   ...                   ...
# 9970                             Dinosaur  1985  9970_8oIf_lp0ewY.wav
# 9971       Why can't we live together Rmx  2001  9971_nSPk9hBwJ44.wav
# 9972                         Tall Stories  1996                   NaN
# 9973  Sex_ Anarchy & Rock N' Roll Swindle  2014                   NaN
# 9974                Ultimate Toni Braxton  2003  9974_tLJPsHhcEOo.wav
# 9975         The Soul Of Jazz (Jazz Club)  1967  9975_kTwU6hRyWEE.wav
# 9976                From Hell...With Love  2005                   NaN
# 9977                               Kissed  2010                   NaN
# 9978                                 Them  2003  9978_FlhncpCYLWg.wav
# 9979              The Best Of Ivan Parker  2005                   NaN
# 9980                            Boomerang  2003  9980_DQ7VqKYlnP0.wav
# 9981                  Not Without A Fight  2009  9981_W1uWuwQGzlU.wav
# 9982       Todos Cantamos Con Maria Elena  2000  9982_jwrorkjjuiw.wav
# 9983                       I'm Still Here  1996  9983_pyk2dTAxNV0.wav
# 9984                  Let The Movie Begin  1978  9984_AtpyAVzdXVw.wav
# 9985                      Genesis And Job  1994  9985_R6fFFLFHO3U.wav
# 9986    Kaskaad - Mohawk Hunt / Earuption     0                   NaN
# 9987                               Beladi  2005  9987_4E4emmpSjMI.wav
# 9988                                  111  2006  9988_beUCE6WMj4g.wav
# 9989                               Sirens  2006  9989_rV1YchH9Mqw.wav
# 9990                    The Sporting Life  2000                   NaN
# 9991              Return Of The Guardians  1996  9991_BMtS-RrqMf0.wav
# 9992                         Gift Grub 10     0                   NaN
# 9993      The Unforgettable Grandpa Jones  1959  9993_qEQsEzJ223A.wav
# 9994             Praise God I'm Satisfied  1989  9994_oKxdqLqOtgs.wav
# 9995                         Sin / Pecado  1998  9995_nt_zxoWySWU.wav
# 9996                           Collection  1998  9996_CsjhZs5mF1w.wav
# 9997                              Reality  2002  9997_tv3-Wj3qjQs.wav
# 9998                       Nouveau Zydeco  1991  9998_buBxTx1SiqE.wav
# 9999           Once Upon A Shattered Life  2005  9999_-OSqb2Sg2KU.wav
#
#        status replacement_link  \
# 0       valid              NaN
# 1       valid              NaN
# 2       valid              NaN
# 3       valid              NaN
# 4       valid              NaN
# 5     invalid              NaN
# 6     invalid              NaN
# 7       valid              NaN
# 8       valid              NaN
# 9       valid              NaN
# 10      valid              NaN
# 11      valid              NaN
# 12    invalid              NaN
# 13    invalid              NaN
# 14      valid              NaN
# 15      valid              NaN
# 16      valid              NaN
# 17    invalid              NaN
# 18      valid              NaN
# 19    invalid              NaN
# 20      valid              NaN
# 21      valid              NaN
# 22    invalid              NaN
# 23      valid              NaN
# 24      valid              NaN
# 25      valid              NaN
# 26      valid              NaN
# 27      valid              NaN
# 28      valid              NaN
# 29      valid              NaN
# ...       ...              ...
# 9970    valid              NaN
# 9971    valid              NaN
# 9972  invalid              NaN
# 9973  invalid              NaN
# 9974    valid              NaN
# 9975    valid              NaN
# 9976  invalid              NaN
# 9977  invalid              NaN
# 9978    valid              NaN
# 9979  invalid              NaN
# 9980    valid              NaN
# 9981    valid              NaN
# 9982    valid              NaN
# 9983    valid              NaN
# 9984    valid              NaN
# 9985    valid              NaN
# 9986  invalid              NaN
# 9987    valid              NaN
# 9988    valid              NaN
# 9989    valid              NaN
# 9990  invalid              NaN
# 9991    valid              NaN
# 9992  invalid              NaN
# 9993    valid              NaN
# 9994    valid              NaN
# 9995    valid              NaN
# 9996    valid              NaN
# 9997    valid              NaN
# 9998    valid              NaN
# 9999    valid              NaN
#
#                                                yt_query  \
# 0                               Casual I Didn't Mean To
# 1                                The Box Tops Soul Deep
# 2                      Sonora Santanera Amor De Cabaret
# 3                              Adam Ant Something Girls
# 4                                    Gob Face the Ashes
# 5                                                   NaN
# 6                                                   NaN
# 7                    Tweeterfriendly Music Drop of Rain
# 8                           Planet P Project Pink World
# 9                 Clp Insatiable (Instrumental Version)
# 10                         JennyAnyKind Young Boy Blues
# 11                Wayne Watson The Urgency (LP Version)
# 12                                                  NaN
# 13                                                  NaN
# 14                Lionel Richie Tonight Will Be Alright
# 15                                  Blue Rodeo Floating
# 16                            Richard Souther High Tide
# 17                                                  NaN
# 18                              Tesla Caught In A Dream
# 19                                                  NaN
# 20              Jimmy Wakely Broken-Down Merry-Go-Round
# 21                            Alice Stuart Kassie Jones
# 22                                                  NaN
# 23    The Dillinger Escape Plan Setting Fire to Slee...
# 24          SUE THOMPSON James (Hold The Ladder Steady)
# 25                 Five Bolt Main Made Like This (Live)
# 26                                Clp Superconfidential
# 27    Tim Wilson I Think My Wife Is Running Around O...
# 28                           Willie Bobo Spanish Grease
# 29                      Faye Adams Crazy Mixed Up World
# ...                                                 ...
# 9970                         Dinosaur Jr. Does It Float
# 9971               Sin Plomo Why can't we live together
# 9972                                                NaN
# 9973                                                NaN
# 9974    Toni Braxton Featuring Babyface Give U My Heart
# 9975                        Cal Tjader Along Comes Mary
# 9976                                                NaN
# 9977                                                NaN
# 9978                        themselves Crayon Sharpener
# 9979                                                NaN
# 9980                               Daara J Le Precipice
# 9981        New Found Glory Don't Let Her Pull You Down
# 9982                 Mar√≠a Elena Walsh La Mona Jacinta
# 9983                 Mindy McCready Ten Thousand Angels
# 9984                        Joy Division Leaders Of Men
# 9985             Don Francisco Overture (Genesis & Job)
# 9986                                                NaN
# 9987                           Chantal Chamandy Zindegi
# 9988     Mouth Of The Architect Harboring An Apparition
# 9989          It Dies Today One the road (to Damnation)
# 9990                                                NaN
# 9991               David Arkenstone The Forgotten Lands
# 9992                                                NaN
# 9993                        Grandpa Jones Down In Dixie
# 9994        Blind Willie Johnson God Don't Never Change
# 9995                           Moonspell The Hanged Man
# 9996    Danny Williams The Wonderful World Of The Young
# 9997                      Winston Reedy Sentimental Man
# 9998         Myrick "Freeze" Guillory Zydeco In D-Minor
# 9999                 Seventh Day Slumber Shattered Life
#
#                                                yt_title  \
# 0                      Casual - I Didn't Mean To [1994]
# 1                       Soul Deep The Box Tops {Stereo}
# 2                 Amor De Cabaret - La Sonora Santanera
# 3                         adam ant- something girls.mpg
# 4                                  Gob - Face The Ashes
# 5                                                   NaN
# 6                                                   NaN
# 7                                          Drop of Rain
# 8                                            Pink World
# 9                             Insatiable (Instrumental)
# 10                                   Young Boy Blues #2
# 11                                          The Urgency
# 12                                                  NaN
# 13                                                  NaN
# 14                              Tonight Will Be Alright
# 15                                             Floating
# 16                         High Tide by Richard Souther
# 17                                                  NaN
# 18                          Caught Up In A Dream, Tesla
# 19                                                  NaN
# 20    Margaret Whiting & Jimmy Wakely — Broken Down ...
# 21                                         Kassie Jones
# 22                                                  NaN
# 23    The DILLINGER ESCAPE PLAN - "Setting Fire To S...
# 24        Sue Thompson - James (Hold The Ladder Steady)
# 25                    "Made Like This" - Five Bolt Main
# 26                                    Superconfidential
# 27    I Think My Wife Is Running Around On Me (Taco ...
# 28                         Willie Bobo   Spanish Grease
# 29                    Faye Adams - Crazy Mixed Up World
# ...                                                 ...
# 9970                       Dinosaur Jr. - Does It Float
# 9971  Sin Plomo feat. Boris G. - Why Can't We Live T...
# 9972                                                NaN
# 9973                                                NaN
# 9974  Babyface - Give U My Heart (Album Radio Edit V...
# 9975                      Cal Tjader - Along Comes Mary
# 9976                                                NaN
# 9977                                                NaN
# 9978                 Themselves - The Crayon Sharperner
# 9979                                                NaN
# 9980                             Daara J- Le pr√©cipice
# 9981    New Found Glory - "Don't Let Her Pull You Down"
# 9982  La Mona Jacinta - Canciones de Mar√≠a Elena Walsh
# 9983               Mindy McCready - Ten Thousand Angels
# 9984                      Joy Division - Leaders of Men
# 9985                      Genesis & Job - Don Francisco
# 9986                                                NaN
# 9987                    Zindegi - Chantal Chamandy live
# 9988   Mouth of the Architect - Harboring an Apparition
# 9989                        One The Road (To Damnation)
# 9990                                                NaN
# 9991             David Arkenstone - The Forgotten Lands
# 9992                                                NaN
# 9993                Grandpa Jones - Are You from Dixie?
# 9994      Blind Willie Johnson - God Don't Never Change
# 9995                         Moonspell - The Hanged Man
# 9996  Danny Williams. The Wonderful World Of The Young.
# 9997                                    Sentimental Man
# 9998                                  Zydeco In D-Minor
# 9999                 Seventh Day Slumber-Shattered Life
#
#                                                 yt_link
# 0           https://www.youtube.com/watch?v=gHGYEljjY2M
# 1           https://www.youtube.com/watch?v=6VFEIfh2m-g
# 2           https://www.youtube.com/watch?v=oScZuIp6ce8
# 3           https://www.youtube.com/watch?v=dISqPMADs00
# 4           https://www.youtube.com/watch?v=kvZiH1k_5_s
# 5                                                   NaN
# 6                                                   NaN
# 7           https://www.youtube.com/watch?v=PrSAS9lf2eA
# 8           https://www.youtube.com/watch?v=BSJK6YKLmEQ
# 9           https://www.youtube.com/watch?v=YTC8xsagZgY
# 10          https://www.youtube.com/watch?v=f5URcnD452c
# 11          https://www.youtube.com/watch?v=6PGsnAbvCFw
# 12                                                  NaN
# 13                                                  NaN
# 14          https://www.youtube.com/watch?v=8ZZz44Y2DPg
# 15          https://www.youtube.com/watch?v=ODopp17DeOs
# 16          https://www.youtube.com/watch?v=_G7ncNXlScw
# 17                                                  NaN
# 18          https://www.youtube.com/watch?v=-Tgtl5FOGNY
# 19                                                  NaN
# 20          https://www.youtube.com/watch?v=z2l7Squ65xs
# 21          https://www.youtube.com/watch?v=V3S5y-C60xY
# 22                                                  NaN
# 23          https://www.youtube.com/watch?v=2dQ2-t_v25g
# 24          https://www.youtube.com/watch?v=laEwOj5qXNo
# 25          https://www.youtube.com/watch?v=SiOQWCrS0G4
# 26          https://www.youtube.com/watch?v=ogTkHhv8-GI
# 27          https://www.youtube.com/watch?v=iHYIReJEnQI
# 28          https://www.youtube.com/watch?v=o34TbQOzhkU
# 29          https://www.youtube.com/watch?v=rruPJjeeIAI
# ...                                                 ...
# 9970         http://www.youtube.com/watch?v=8oIf_lp0ewY
# 9971         http://www.youtube.com/watch?v=nSPk9hBwJ44
# 9972                                                NaN
# 9973                                                NaN
# 9974         http://www.youtube.com/watch?v=tLJPsHhcEOo
# 9975         http://www.youtube.com/watch?v=kTwU6hRyWEE
# 9976                                                NaN
# 9977                                                NaN
# 9978         http://www.youtube.com/watch?v=FlhncpCYLWg
# 9979                                                NaN
# 9980         http://www.youtube.com/watch?v=DQ7VqKYlnP0
# 9981         http://www.youtube.com/watch?v=W1uWuwQGzlU
# 9982         http://www.youtube.com/watch?v=jwrorkjjuiw
# 9983         http://www.youtube.com/watch?v=pyk2dTAxNV0
# 9984         http://www.youtube.com/watch?v=AtpyAVzdXVw
# 9985  http://www.youtube.com/watch?v=R6fFFLFHO3U&lis...
# 9986                                                NaN
# 9987         http://www.youtube.com/watch?v=4E4emmpSjMI
# 9988         http://www.youtube.com/watch?v=beUCE6WMj4g
# 9989         http://www.youtube.com/watch?v=rV1YchH9Mqw
# 9990                                                NaN
# 9991         http://www.youtube.com/watch?v=BMtS-RrqMf0
# 9992                                                NaN
# 9993         http://www.youtube.com/watch?v=qEQsEzJ223A
# 9994         http://www.youtube.com/watch?v=oKxdqLqOtgs
# 9995         http://www.youtube.com/watch?v=nt_zxoWySWU
# 9996         http://www.youtube.com/watch?v=CsjhZs5mF1w
# 9997         http://www.youtube.com/watch?v=tv3-Wj3qjQs
# 9998         http://www.youtube.com/watch?v=buBxTx1SiqE
# 9999         http://www.youtube.com/watch?v=-OSqb2Sg2KU
#
# [10000 rows x 12 columns]

# %%
def get_time_series(filename):
    audio, sr = librosa.load('data/' + filename, sr=sampling_rate, 
                            offset=25, duration=3)
    return audio

audio = data['filename'].apply(get_time_series)

# %%
pickle.dump(audio, open("audio.p", "wb"))

# %%
audio = pickle.load(open("audio.p", "rb"))

# %%
# X_train = X.apply(pd.Series)
n = len(audio)
m = len(audio.values[:len(audio.values)//2])
# m = 1024
progress = IntProgress(min=0, max=n) # instantiate the bar
label = HTML()
box = HBox(children=[progress, label])
display(box)

rows = []
# X_train = pd.DataFrame(index=np.arange(0, n), columns=np.arange(0, m))
for row in audio:
    if (len(row) < m):
        print("ERROR", len(row))
        break
#     X_train.iloc[progress.value] = row[:m]
    rows.append(pd.Series(row[:m]))
    progress.value += 1
    label.value = u'{name}: {index} / {size}'.format(
                    name='rows converted',
                    index=progress.value,
                    size=n)

X = pd.DataFrame(rows)
# Out:
# HBox(children=(IntProgress(value=0, max=7293), HTML(value='')))

# %%
X.to_csv("audio.csv")

# %%
X = pd.read_csv("audio.csv", index_col=0).values
X = np.expand_dims(X, axis=2)
X.shape
# Out:
# (7293, 3646, 1)

# %%
depth = X.shape[1]
num_classes = labels.shape[1]
def baseline_model():
    model = Sequential([
        Conv1D(128, 256, strides=128, activation = 'relu', 
               padding = 'valid', input_shape = X.shape[1:]),
        Flatten(),
        Dense(64, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])
    
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['acc'])
    return model

estimator = KerasClassifier(build_fn=baseline_model, epochs=20, 
                            batch_size=5, verbose=1)

# %%
kfold = KFold(n_splits=4, shuffle=True, random_state=seed)
results = cross_val_score(estimator, X, labels, cv=kfold)
print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# WARNING:tensorflow:From /usr/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/20
#
# 5834/5834 [==============================] - 5s 935us/step - loss: 0.3986 - acc: 0.8581
# Epoch 12/20
# 5834/5834 [==============================] - 6s 944us/step - loss: 0.3552 - acc: 0.8720
# Epoch 13/20
# 5834/5834 [==============================] - 6s 953us/step - loss: 0.3005 - acc: 0.8934
# Epoch 14/20
# 5834/5834 [==============================] - 6s 959us/step - loss: 0.2639 - acc: 0.9100
# Epoch 15/20
# 5834/5834 [==============================] - 6s 956us/step - loss: 0.2441 - acc: 0.9181
# Epoch 16/20
# 5834/5834 [==============================] - 6s 966us/step - loss: 0.2270 - acc: 0.9278
# Epoch 17/20
# 5834/5834 [==============================] - 6s 970us/step - loss: 0.2320 - acc: 0.9258
# Epoch 18/20
# 5834/5834 [==============================] - 6s 975us/step - loss: 0.2013 - acc: 0.9383
# Epoch 19/20
# 5834/5834 [==============================] - 6s 959us/step - loss: 0.1549 - acc: 0.9529
# Epoch 20/20
# 5834/5834 [==============================] - 6s 965us/step - loss: 0.2032 - acc: 0.9379

# %%
pickle.dump(estimator, open("time_series_model.p", "wb"))

# %%
estimator = pickle.load(open("time_series_model.p", "rb"))

# %%
estimator.predict_proba(X).shape
# Out:
# 7293/7293 [==============================] - 2s 232us/step
# (7293, 10)

# %%
# pred = pd.Series(estimator.predict_proba(spectral).flatten(), index=encoder.inverse_transform(np.arange(10)))
pred = pd.DataFrame(raw_data[raw_data['status'] == 'valid']['idx'])
pred['1910'] = 0
pred = pred.join(pd.DataFrame(estimator.predict_proba(X), index=pred.index, columns=encoder.inverse_transform(np.arange(10))))
pred.shape
# Out:
# 7293/7293 [==============================] - 2s 235us/step
# (7293, 12)

# %%
pred.to_csv("time_series_pred.csv")

# %%
def get_freq_domain(filename):
    """
    Like in the github article, I used windows of 2048 timesteps,
    with 1024 timesteps overlap between spectrogram frames.
    I'm using a sampling frequency of 22.05 kHz.
    """
    y, sr = librosa.load('data/' + filename, sr=sampling_rate, 
                         offset=20, duration=10)
    M = melspectrogram(y, sr, n_fft=2048, hop_length=1024)
    return M

# %%
n = len(data)
progress = IntProgress(min=0, max=n) # instantiate the bar
label = HTML()
box = HBox(children=[progress, label])
display(box)

rows = []
for filename in data['filename']:
    rows.append(get_freq_domain(filename))
    progress.value += 1
    label.value = u'{name}: {index} / {size}'.format(
                    name='rows converted',
                    index=progress.value,
                    size=n)
pickle.dump(rows, open("raw_freq.p", "wb"))

# %%
rows = pickle.load(open("raw_freq.p", "rb"))

# %%
X = np.array(rows)
X = np.expand_dims(X, axis=3)
X.shape
# Out:
# (7293, 128, 216, 1)

# %%
num_classes = labels.shape[1]
def baseline_model():
    model = Sequential([
        Conv2D(64, (4, 6), strides=(2, 3), activation = 'relu', 
               padding = 'valid', input_shape = X.shape[1:]),
        Flatten(),
        Dense(32, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])
    model.compile(loss='categorical_crossentropy', optimizer='adam', 
                  metrics=['acc'])

    return model

estimator = KerasClassifier(build_fn=baseline_model, epochs=20, 
                            batch_size=5, verbose=1)

# %%
kfold = KFold(n_splits=4, shuffle=True, random_state=seed)
results = cross_val_score(estimator, X, labels, cv=kfold)
print("Baseline: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))
# Out:
# Epoch 1/20
# 5469/5469 [==============================] - 184s 34ms/step - loss: 10.1421 - acc: 0.3688
# Epoch 2/20
# 5469/5469 [==============================] - 184s 34ms/step - loss: 7.9839 - acc: 0.5047
# Epoch
20
# 5470/5470 [==============================] - 182s 33ms/step - loss: 1.4058 - acc: 0.5018
# Epoch 18/20
# 5470/5470 [==============================] - 183s 33ms/step - loss: 1.4055 - acc: 0.5018
# Epoch 19/20
# 5470/5470 [==============================] - 182s 33ms/step - loss: 1.4054 - acc: 0.5018
# Epoch 20/20
# 5470/5470 [==============================] - 180s 33ms/step - loss: 1.4051 - acc: 0.5018
# 1823/1823 [==============================] - 5s 3ms/step
# Baseline: 47.59% (4.15%)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, labels, train_size=0.8, random_state=seed)
estimator.fit(X_train, y_train)
# Out:
# Epoch 1/20
# 5834/5834 [==============================] - 186s 32ms/step - loss: 8.5036 - acc: 0.3660
# Epoch 2/20
# 5834/5834 [==============================] - 185s 32ms/step - loss: 1.6293 - acc: 0.5029
# Epoch 3/20
# 5834/5834 [==============================] - 185s 32ms/step - loss: 1.4576 - acc: 0.5060
# Epoch 4/20
# 5834/5834 [==============================] - 185s 32ms/step - loss: 1.4120 - acc: 0.5051
# Epoch 5/20
# 5834/5834 [==============================] - 185s 32ms/step - loss: 1.4010 - acc: 0.5055
# Epoch 6/20
# 5834/5834 [==============================] - 185s 32ms/step - loss: 1.3992 - acc: 0.5057
# Epoch 7/20
# 5834/5834 [==============================] - 186s 32ms/step - loss: 1.3940 - acc: 0.5058
# Epoch 8/20
# 5834/5834 [==============================] - 187s 32ms/step - loss: 1.3943 - acc: 0.5057
# Epoch 9/20
# 5834/5834 [==============================] - 186s 32ms/step - loss: 1.3902 - acc: 0.5060
# Epoch 10/20
# 5834/5834 [==============================] - 186s 32ms/step - loss: 1.3899 - acc: 0.5060
# Epoch 11/20
# 5834/5834 [==============================] - 186s 32ms/step - loss: 1.3917 - acc: 0.5060
# Epoch 12/20
# 5834/5834 [==============================] - 186s 32ms/step - loss: 1.3986 - acc: 0.5060
# Epoch 13/20
# 5834/5834 [==============================] - 186s 32ms/step - loss: 1.3973 - acc: 0.5069
# Epoch 14/20
# 5834/5834 [==============================] - 186s 32ms/step - loss: 1.3879 - acc: 0.5069
# Epoch 15/20
# 5834/5834 [==============================] - 187s 32ms/step - loss: 1.3886 - acc: 0.5065
# Epoch 16/20
# 5834/5834 [==============================] - 187s 32ms/step - loss: 1.3882 - acc: 0.5067
# Epoch 17/20
# 5834/5834 [==============================] - 187s 32ms/step - loss: 1.3990 - acc: 0.5063
# Epoch 18/20
# 5834/5834 [==============================] - 187s 32ms/step - loss: 1.3887 - acc: 0.5067
# Epoch 19/20
# 5834/5834 [==============================] - 187s 32ms/step - loss: 1.3898 - acc: 0.5067
# Epoch 20/20
# 5834/5834 [==============================] - 187s 32ms/step - loss: 1.3886 - acc: 0.5067

# %%
pickle.dump(estimator, open("freq_domain_model.p", "wb"))

# %%
estimator = pickle.load(open("freq_domain_model.p", "rb"))

# %%
# pred = pd.Series(estimator.predict_proba(spectral).flatten(), index=encoder.inverse_transform(np.arange(10)))
pred = pd.DataFrame(raw_data[raw_data['status'] == 'valid']['idx'])
pred['1910'] = 0
pred = pred.join(pd.DataFrame(estimator.predict_proba(X), index=pred.index, columns=encoder.inverse_transform(np.arange(10))))
pred.shape
# Out:
# 7293/7293 [==============================] - 18s 2ms/step
# (7293, 12)

# %%
pred.to_csv("freq_domain_pred.csv")
